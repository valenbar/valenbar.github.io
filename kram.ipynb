# %%
import pandas as pd
import json

with open("data/database.json", "r", encoding="utf-8") as f:
    data = json.load(f)

df = pd.read_json(json.dumps(data["users"]), orient="index")

# %%
display(df.sample(10))
# Out:
#                                     name         username  verified  \
# 249379766                    Thomas Jane       ThomasJane      True
# 832256897709400064      WB Games Support   WBGamesSupport      True
# 288662354             Ryan ten Doeschate         rtendo27      True
# 28635233                            DKNY             dkny      True
# 462513479             Skylar Laine James     Skylar_Laine     False
# 2598371538                       EA Play           EAPlay      True
# 2429051735                 Navy Football           NavyFB      True
# 918539343811235840  Crime Junkie Podcast   CrimeJunkiePod      True
# 278132803               Zero Skateboards  zeroskateboards     False
# 630523185                         rachel       bugposting     False
#
#                     followers_count  following_count  tweet_count  \
# 249379766                     83615             1112         1995
# 832256897709400064            51325               34        33609
# ...
